# %% [markdown]
# # Created by: Prateek Kumar

# %%
#Importing Pandas
import pandas as pd

# %%
#Reading from CSV File into a dataframe usinng relative path
df = pd.read_csv("../assignment_1.csv")

# %%
#Displaying first 10 rows of data
df.head(10)
# Out:
#          date  nominal_effective_exchange_rate  effective_federal_funds_rate  \
# 0  1985-02-01                       171.491304                          8.35
# 1  1985-03-01                       176.187000                          8.50
# 2  1985-05-01                       170.949545                          8.27
# 3  1985-06-01                       171.393913                          7.97
# 4  1985-08-01                       164.653478                          7.88
# 5  1985-10-01                       163.872857                          7.92
# 6  1985-11-01                       156.121304                          7.99
# 7  1986-01-01                       152.637727                          8.27
# 8  1986-02-01                       151.536087                          8.14
# 9  1986-03-01                       146.601500                          7.86
#
#    cpi_index  djia_adj_close  gold_price
# 0      105.3     1286.770020       299.1
# ...

# %%
#using Describe to understand the features of data
df.describe()
# Out:
#        nominal_effective_exchange_rate  effective_federal_funds_rate  \
# count                       296.000000                    296.000000
# mean                        115.890172                      3.621047
# std                          14.636330                      2.794171
# min                          91.683043                      0.070000
# 25%                         106.889269                      0.995000
# 50%                         114.592826                      3.560000
# 75%                         121.318556                      5.560000
# max                         176.187000                      9.850000
#
#         cpi_index  djia_adj_close   gold_price
# count  296.000000      296.000000   296.000000
# mean   180.961818     9664.794209   686.019257
# std     45.264254     6258.804946   449.786208
# min    105.300000     1258.060059   256.100000
# 25%    142.300000     3633.209961   352.175000
# 50%    179.600000    10018.145020   408.850000
# ...

# %%
#Plotting the bar graphs for the features.
hist = df.hist(bins=50)

# %%
#Plotting box plot for the data. 'Vert' for horizontal alignment since the attributes looked too cluttered and not redable in vertical alignment 
df.plot.box(vert=False);

# %%
#Plotting the line chart for the features. 
df.plot(figsize=(8, 6));

# %%
#Plotting the line chart with subplot for individual features. 
df.plot(figsize=(8, 6), subplots=True);
